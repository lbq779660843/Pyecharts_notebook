# %% [markdown]
# <!--BOOK_INFORMATION-->
# <a href="https://user-images.githubusercontent.com/19553554/71825144-2d568180-30d6-11ea-8ee0-63c849cfd934.png" target="_blank"><img align="left" style="width: 76px; height: 100px; background: white; padding: 1px; border: 1px solid black; margin-right:10px;"></a>
# *pyecharts 是一个用于生成 Echarts 图表的类库。Echarts 是百度开源的一个数据可视化 JS 库。用 Echarts 生成的图可视化效果非常棒，为了与 Python 进行对接，方便在 Python 中直接使用数据生成图，于是有人开发出了这个项目[GitHub](https://github.com/pyecharts/pyecharts) .*
#
# *Note.建议本程序在参看https://github.com/pyecharts/pyecharts 的安装步骤后再运行； 本程序所有的例子都是从官方提供的样例代码[GitHub](https://github.com/pyecharts/pyecharts-gallery)中提取的,如果对某个API有疑问建议在IDE里面查看*
#
# *Echart类型图种大全:https://echarts.apache.org/examples/zh/#chart-type-line pyecharts图导入到ppt中的方法:https://baijiahao.baidu.com/s?id=1663839456876951842&wfr=spider&for=pc.*
#
# *作者: LBQ; 时间:2020/7/24. 邮箱:779660843@qq.com*

# %% [markdown]
# # XIII.图像组件

# %% [markdown]
# 主要就是在图形中添加外部的图像组件，可以自定义设置

# %% [markdown]
# ## 基础示例

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

bgi = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-Graphic Image 组件示例"),
        graphic_opts=[
            opts.GraphicImage(
                graphic_item=opts.GraphicItem(
                    id_="logo", right=20, top=20, z=-10, bounding="raw", origin=[75, 75]
                ),
                graphic_imagestyle_opts=opts.GraphicImageStyleOpts(###图形学组件
                    image="https://www.echartsjs.com/zh/images/favicon.png",
                    width=150,
                    height=150,
                    opacity=0.4,
                ),
            )
        ],
    )
    #.render("graphic_image.html")
)
bgi.load_javascript()
bgi.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f81015b307034d3a9d02b128d50236ac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f81015b307034d3a9d02b128d50236ac = echarts.init(
#                     document.getElementById('f81015b307034d3a9d02b128d50236ac'), 'white', {renderer: 'canvas'});
#                 var option_f81015b307034d3a9d02b128d50236ac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 88,
#                 122,
#                 98,
#                 52,
#                 115,
#                 30,
#                 33
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 44,
#                 76,
#                 22,
#                 39,
#                 44,
#                 107,
#                 26
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Image \u7ec4\u4ef6\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "graphic": [
#         {
#             "type": "image",
#             "id": "logo",
#             "$action": "merge",
#             "rotation": 0,
#             "origin": [
#                 75,
#                 75
#             ],
#             "right": 20,
#             "top": 20,
#             "bounding": "raw",
#             "z": -10,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0,
#             "style": {
#                 "image": "https://www.echartsjs.com/zh/images/favicon.png",
#                 "x": 0,
#                 "y": 0,
#                 "width": 150,
#                 "height": 150,
#                 "opacity": 0.4
#             }
#         }
#     ]
# };
#                 chart_f81015b307034d3a9d02b128d50236ac.setOption(option_f81015b307034d3a9d02b128d50236ac);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid
from pyecharts.faker import Faker

bar = (
    Bar(init_opts=opts.InitOpts(chart_id="1234"))
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-Graphic Image（旋转功能）组件示例"),
        graphic_opts=[
            opts.GraphicImage(
                graphic_item=opts.GraphicItem(
                    id_="logo", right=20, top=20, z=-10, bounding="raw", origin=[75, 75]
                ),
                graphic_imagestyle_opts=opts.GraphicImageStyleOpts(
                    image="https://www.echartsjs.com/zh/images/favicon.png",
                    width=150,
                    height=150,
                    opacity=0.4,
                ),
            )
        ],
    )
)
c = (
    Grid(init_opts=opts.InitOpts(chart_id="1234"))
    .add(
        chart=bar,
        grid_opts=opts.GridOpts(pos_left="5%", pos_right="4%", pos_bottom="5%"),
    )
    .add_js_funcs(
        """
        var rotation = 0;
        setInterval(function () {
            chart_1234.setOption({
                graphic: {
                    id: 'logo',
                    rotation: (rotation += Math.PI / 360) % (Math.PI * 2)
                }
            });
        }, 30);
    """
    )
    #.render("graphic_image_with_js.html")
)
c.load_javascript()
c.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/composite_charts/grid.py:17: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9f49a0bced08461bb1ee74f7739f6942" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9f49a0bced08461bb1ee74f7739f6942 = echarts.init(
#                     document.getElementById('9f49a0bced08461bb1ee74f7739f6942'), 'white', {renderer: 'canvas'});
#
#         var rotation = 0;
#         setInterval(function () {
#             chart_1234.setOption({
#                 graphic: {
#                     id: 'logo',
#                     rotation: (rotation += Math.PI / 360) % (Math.PI * 2)
#                 }
#             });
#         }, 30);
#
#                 var option_9f49a0bced08461bb1ee74f7739f6942 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 137,
#                 104,
#                 48,
#                 106,
#                 30,
#                 101,
#                 118
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 140,
#                 61,
#                 121,
#                 88,
#                 87,
#                 47,
#                 33
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Image\uff08\u65cb\u8f6c\u529f\u80fd\uff09\u7ec4\u4ef6\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "graphic": [
#         {
#             "type": "image",
#             "id": "logo",
#             "$action": "merge",
#             "rotation": 0,
#             "origin": [
#                 75,
#                 75
#             ],
#             "right": 20,
#             "top": 20,
#             "bounding": "raw",
#             "z": -10,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0,
#             "style": {
#                 "image": "https://www.echartsjs.com/zh/images/favicon.png",
#                 "x": 0,
#                 "y": 0,
#                 "width": 150,
#                 "height": 150,
#                 "opacity": 0.4
#             }
#         }
#     ],
#     "grid": [
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "left": "5%",
#             "right": "4%",
#             "bottom": "5%",
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         }
#     ]
# };
#                 chart_9f49a0bced08461bb1ee74f7739f6942.setOption(option_9f49a0bced08461bb1ee74f7739f6942);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker


c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-Graphic Rect+Text 1 组件示例"),
        graphic_opts=[
            opts.GraphicGroup(
                graphic_item=opts.GraphicItem(
                    rotation=JsCode("Math.PI / 4"),
                    bounding="raw",
                    right=110,
                    bottom=110,
                    z=100,
                ),
                children=[
                    opts.GraphicRect(
                        graphic_item=opts.GraphicItem(
                            left="center", top="center", z=100
                        ),
                        graphic_shape_opts=opts.GraphicShapeOpts(width=400, height=50),
                        graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                            fill="rgba(0,0,0,0.3)"
                        ),
                    ),
                    opts.GraphicText(
                        graphic_item=opts.GraphicItem(
                            left="center", top="center", z=100
                        ),
                        graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                            text="pyecharts bar chart",
                            font="bold 26px Microsoft YaHei",
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="#fff"
                            ),
                        ),
                    ),
                ],
            )
        ],
    )
    #.render("graphic_rect_bar0.html")
)
c.load_javascript()
c.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a7f044f96e474c0a830e39276bae45da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a7f044f96e474c0a830e39276bae45da = echarts.init(
#                     document.getElementById('a7f044f96e474c0a830e39276bae45da'), 'white', {renderer: 'canvas'});
#                 var option_a7f044f96e474c0a830e39276bae45da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 54,
#                 127,
#                 66,
#                 97,
#                 132,
#                 146,
#                 68
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 113,
#                 136,
#                 108,
#                 45,
#                 147,
#                 70,
#                 109
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Rect+Text 1 \u7ec4\u4ef6\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "graphic": [
#         {
#             "type": "group",
#             "diffChildrenByName": false,
#             "children": [
#                 {
#                     "type": "rect",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "shape": {
#                         "x": 0,
#                         "y": 0,
#                         "width": 400,
#                         "height": 50
#                     },
#                     "style": {
#                         "fill": "rgba(0,0,0,0.3)",
#                         "line_width": 0
#                     }
#                 },
#                 {
#                     "type": "text",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "center",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "style": {
#                         "text": "pyecharts bar chart",
#                         "x": 0,
#                         "y": 0,
#                         "font": "bold 26px Microsoft YaHei",
#                         "textAlign": "left",
#                         "fill": "#fff",
#                         "line_width": 0
#                     }
#                 }
#             ],
#             "$action": "merge",
#             "rotation": Math.PI / 4,
#             "right": 110,
#             "bottom": 110,
#             "bounding": "raw",
#             "z": 100,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
#             "ignore": false,
#             "cursor": "pointer",
#             "draggable": false,
#             "progressive": false,
#             "width": 0,
#             "height": 0
#         }
#     ]
# };
#                 chart_a7f044f96e474c0a830e39276bae45da.setOption(option_a7f044f96e474c0a830e39276bae45da);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker

c = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Bar-Graphic Rect+Text 2 组件示例"),
        graphic_opts=[
            opts.GraphicGroup(
                graphic_item=opts.GraphicItem(left="50%", top="15%"),
                children=[
                    opts.GraphicRect(
                        graphic_item=opts.GraphicItem(
                            z=100, left="center", top="middle"
                        ),
                        graphic_shape_opts=opts.GraphicShapeOpts(width=190, height=90),
                        graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                            fill="#fff",
                            stroke="#555",
                            line_width=2,
                            shadow_blur=8,
                            shadow_offset_x=3,
                            shadow_offset_y=3,
                            shadow_color="rgba(0,0,0,0.3)",
                        ),
                    ),
                    opts.GraphicText(
                        graphic_item=opts.GraphicItem(
                            left="center", top="middle", z=100
                        ),
                        graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                            text=JsCode(
                                "['横轴表示数据类别',"
                                "'纵轴表示数值的值',"
                                "'这个文本块可以放在图中各',"
                                "'种位置'].join('\\n')"
                            ),
                            font="14px Microsoft YaHei",
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="#333"
                            ),
                        ),
                    ),
                ],
            )
        ],
    )
    #.render("graphic_rect_bar1.html")
)
c.load_javascript()
c.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f94407a68c754620af3a4e3f3fc21126" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f94407a68c754620af3a4e3f3fc21126 = echarts.init(
#                     document.getElementById('f94407a68c754620af3a4e3f3fc21126'), 'white', {renderer: 'canvas'});
#                 var option_f94407a68c754620af3a4e3f3fc21126 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 79,
#                 59,
#                 31,
#                 145,
#                 112,
#                 140,
#                 97
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 23,
#                 109,
#                 64,
#                 98,
#                 62,
#                 47,
#                 29
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-Graphic Rect+Text 2 \u7ec4\u4ef6\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "graphic": [
#         {
#             "type": "group",
#             "diffChildrenByName": false,
#             "children": [
#                 {
#                     "type": "rect",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "middle",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "shape": {
#                         "x": 0,
#                         "y": 0,
#                         "width": 190,
#                         "height": 90
#                     },
#                     "style": {
#                         "fill": "#fff",
#                         "stroke": "#555",
#                         "line_width": 2,
#                         "shadowBlur": 8,
#                         "shadowOffsetX": 3,
#                         "shadowOffsetY": 3,
#                         "shadowColor": "rgba(0,0,0,0.3)"
#                     }
#                 },
#                 {
#                     "type": "text",
#                     "$action": "merge",
#                     "rotation": 0,
#                     "left": "center",
#                     "top": "middle",
#                     "bounding": "all",
#                     "z": 100,
#                     "zlevel": 0,
#                     "silent": false,
#                     "invisible": false,
#                     "ignore": false,
#                     "cursor": "pointer",
#                     "draggable": false,
#                     "progressive": false,
#                     "width": 0,
#                     "height": 0,
#                     "style": {
#                         "text": ['\u6a2a\u8f74\u8868\u793a\u6570\u636e\u7c7b\u522b','\u7eb5\u8f74\u8868\u793a\u6570\u503c\u7684\u503c','\u8fd9\u4e2a\u6587\u672c\u5757\u53ef\u4ee5\u653e\u5728\u56fe\u4e2d\u5404','\u79cd\u4f4d\u7f6e'].join('\n'),
#                         "x": 0,
#                         "y": 0,
#                         "font": "14px Microsoft YaHei",
#                         "textAlign": "left",
#                         "fill": "#333",
#                         "line_width": 0
#                     }
#                 }
#             ],
#             "$action": "merge",
#             "rotation": 0,
#             "left": "50%",
#             "top": "15%",
#             "bounding": "all",
#             "z": 0,
#             "zlevel": 0,
#             "silent": false,
#             "invisible": false,
