# %% [markdown]
# <!--BOOK_INFORMATION-->
# <a href="https://user-images.githubusercontent.com/19553554/71825144-2d568180-30d6-11ea-8ee0-63c849cfd934.png" target="_blank"><img align="left" style="width: 76px; height: 100px; background: white; padding: 1px; border: 1px solid black; margin-right:10px;"></a>
# *pyecharts 是一个用于生成 Echarts 图表的类库。Echarts 是百度开源的一个数据可视化 JS 库。用 Echarts 生成的图可视化效果非常棒，为了与 Python 进行对接，方便在 Python 中直接使用数据生成图，于是有人开发出了这个项目[GitHub](https://github.com/pyecharts/pyecharts) .*
#
# *Note.建议本程序在参看https://github.com/pyecharts/pyecharts 的安装步骤后再运行； 本程序所有的例子都是从官方提供的样例代码[GitHub](https://github.com/pyecharts/pyecharts-gallery)中提取的,如果对某个API有疑问建议在IDE里面查看*
#
# *Echart类型图种大全:https://echarts.apache.org/examples/zh/#chart-type-line pyecharts图导入到ppt中的方法:https://baijiahao.baidu.com/s?id=1663839456876951842&wfr=spider&for=pc.*
#
# *作者: LBQ; 时间:2020/7/24. 邮箱:779660843@qq.com*

# %% [markdown]
# # XXIV.平行数据(Parallel)

# %%
import pyecharts.options as opts
from pyecharts.charts import Parallel

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.baidu.com/examples/editor.html?c=parallel-simple

目前无法实现的功能:

1、
"""

parallel_axis = [
    {"dim": 0, "name": "Price"},
    {"dim": 1, "name": "Net Weight"},
    {"dim": 2, "name": "Amount"},
    {
        "dim": 3,
        "name": "Score",
        "type": "category",
        "data": ["Excellent", "Good", "OK", "Bad"],
    },
]

data = [[12.99, 100, 82, "Good"], [9.99, 80, 77, "OK"], [20, 120, 60, "Excellent"]]


c = (
    Parallel()
    .add_schema(schema=parallel_axis)#平行数据
    .add(
        series_name="",
        data=data,
        linestyle_opts=opts.LineStyleOpts(width=4, opacity=0.5),
    )
    #.render("basic_parallel.html")
)
c.load_javascript()
c.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="64c757cfaf154f27aeef5ffce981f013" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_64c757cfaf154f27aeef5ffce981f013 = echarts.init(
#                     document.getElementById('64c757cfaf154f27aeef5ffce981f013'), 'white', {renderer: 'canvas'});
#                 var option_64c757cfaf154f27aeef5ffce981f013 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "show": true,
#                 "width": 4,
#                 "opacity": 0.5,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "data": [
#                 [
#                     12.99,
#                     100,
#                     82,
#                     "Good"
#                 ],
#                 [
#                     9.99,
#                     80,
#                     77,
#                     "OK"
#                 ],
#                 [
#                     20,
#                     120,
#                     60,
#                     "Excellent"
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "Price"
#         },
#         {
#             "dim": 1,
#             "name": "Net Weight"
#         },
#         {
#             "dim": 2,
#             "name": "Amount"
#         },
#         {
#             "dim": 3,
#             "name": "Score",
#             "type": "category",
#             "data": [
#                 "Excellent",
#                 "Good",
#                 "OK",
#                 "Bad"
#             ]
#         }
#     ]
# };
#                 chart_64c757cfaf154f27aeef5ffce981f013.setOption(option_64c757cfaf154f27aeef5ffce981f013);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Parallel

data = [
    [1, 91, 45, 125, 0.82, 34, 23, "良"],
    [2, 65, 27, 78, 0.86, 45, 29, "良"],
    [3, 83, 60, 84, 1.09, 73, 27, "良"],
    [4, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
    [5, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
    [6, 109, 81, 121, 1.28, 68, 51, "轻度污染"],
    [7, 106, 77, 114, 1.07, 55, 51, "轻度污染"],
    [8, 89, 65, 78, 0.86, 51, 26, "良"],
    [9, 53, 33, 47, 0.64, 50, 17, "良"],
    [10, 80, 55, 80, 1.01, 75, 24, "良"],
    [11, 117, 81, 124, 1.03, 45, 24, "轻度污染"],
    [12, 99, 71, 142, 1.1, 62, 42, "良"],
    [13, 95, 69, 130, 1.28, 74, 50, "良"],
    [14, 116, 87, 131, 1.47, 84, 40, "轻度污染"],
]
c2 = (
    Parallel()
    .add_schema(
        [
            opts.ParallelAxisOpts(dim=0, name="data"),
            opts.ParallelAxisOpts(dim=1, name="AQI"),
            opts.ParallelAxisOpts(dim=2, name="PM2.5"),
            opts.ParallelAxisOpts(dim=3, name="PM10"),
            opts.ParallelAxisOpts(dim=4, name="CO"),
            opts.ParallelAxisOpts(dim=5, name="NO2"),
            opts.ParallelAxisOpts(dim=6, name="CO2"),
            opts.ParallelAxisOpts(
                dim=7,
                name="等级",
                type_="category",
                data=["优", "良", "轻度污染", "中度污染", "重度污染", "严重污染"],
            ),
        ]
    )
    .add("parallel", data)
    .set_global_opts(title_opts=opts.TitleOpts(title="Parallel-Category"))
   # .render("parallel_category.html")
)
c2.load_javascript()
c2.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="623def9f091c4e76bdd7b6bee6c2094c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_623def9f091c4e76bdd7b6bee6c2094c = echarts.init(
#                     document.getElementById('623def9f091c4e76bdd7b6bee6c2094c'), 'white', {renderer: 'canvas'});
#                 var option_623def9f091c4e76bdd7b6bee6c2094c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "parallel",
#             "coordinateSystem": "parallel",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "name": "parallel",
#             "data": [
#                 [
#                     1,
#                     91,
#                     45,
#                     125,
#                     0.82,
#                     34,
#                     23,
#                     "\u826f"
#                 ],
#                 [
#                     2,
#                     65,
#                     27,
#                     78,
#                     0.86,
#                     45,
#                     29,
#                     "\u826f"
#                 ],
#                 [
#                     3,
#                     83,
#                     60,
#                     84,
#                     1.09,
#                     73,
#                     27,
#                     "\u826f"
#                 ],
#                 [
#                     4,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     5,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     6,
#                     109,
#                     81,
#                     121,
#                     1.28,
#                     68,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     7,
#                     106,
#                     77,
#                     114,
#                     1.07,
#                     55,
#                     51,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     8,
#                     89,
#                     65,
#                     78,
#                     0.86,
#                     51,
#                     26,
#                     "\u826f"
#                 ],
#                 [
#                     9,
#                     53,
#                     33,
#                     47,
#                     0.64,
#                     50,
#                     17,
#                     "\u826f"
#                 ],
#                 [
#                     10,
#                     80,
#                     55,
#                     80,
#                     1.01,
#                     75,
#                     24,
#                     "\u826f"
#                 ],
#                 [
#                     11,
#                     117,
#                     81,
#                     124,
#                     1.03,
#                     45,
#                     24,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ],
#                 [
#                     12,
#                     99,
#                     71,
#                     142,
#                     1.1,
#                     62,
#                     42,
#                     "\u826f"
#                 ],
#                 [
#                     13,
#                     95,
#                     69,
#                     130,
#                     1.28,
#                     74,
#                     50,
#                     "\u826f"
#                 ],
#                 [
#                     14,
#                     116,
#                     87,
#                     131,
#                     1.47,
#                     84,
#                     40,
#                     "\u8f7b\u5ea6\u6c61\u67d3"
#                 ]
#             ],
#             "smooth": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "parallel"
#             ],
#             "selected": {
#                 "parallel": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "parallel": {
#         "left": "5%",
#         "right": "13%",
#         "bottom": "10%",
#         "top": "20%"
#     },
#     "parallelAxis": [
#         {
#             "dim": 0,
#             "name": "data",
#             "scale": false
#         },
#         {
#             "dim": 1,
#             "name": "AQI",
#             "scale": false
#         },
#         {
#             "dim": 2,
#             "name": "PM2.5",
#             "scale": false
#         },
#         {
#             "dim": 3,
#             "name": "PM10",
#             "scale": false
#         },
#         {
#             "dim": 4,
#             "name": "CO",
#             "scale": false
#         },
#         {
#             "dim": 5,
#             "name": "NO2",
#             "scale": false
#         },
#         {
#             "dim": 6,
#             "name": "CO2",
#             "scale": false
#         },
#         {
#             "dim": 7,
#             "name": "\u7b49\u7ea7",
#             "data": [
#                 "\u4f18",
#                 "\u826f",
#                 "\u8f7b\u5ea6\u6c61\u67d3",
#                 "\u4e2d\u5ea6\u6c61\u67d3",
#                 "\u91cd\u5ea6\u6c61\u67d3",
#                 "\u4e25\u91cd\u6c61\u67d3"
#             ],
#             "type": "category",
#             "scale": false
#         }
#     ],
#     "title": [
#         {
#             "text": "Parallel-Category",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_623def9f091c4e76bdd7b6bee6c2094c.setOption(option_623def9f091c4e76bdd7b6bee6c2094c);
#         });
#     </script>
