# %% [markdown]
# <!--BOOK_INFORMATION-->
# <a href="https://user-images.githubusercontent.com/19553554/71825144-2d568180-30d6-11ea-8ee0-63c849cfd934.png" target="_blank"><img align="left" style="width: 76px; height: 100px; background: white; padding: 1px; border: 1px solid black; margin-right:10px;"></a>
# *pyecharts 是一个用于生成 Echarts 图表的类库。Echarts 是百度开源的一个数据可视化 JS 库。用 Echarts 生成的图可视化效果非常棒，为了与 Python 进行对接，方便在 Python 中直接使用数据生成图，于是有人开发出了这个项目[GitHub](https://github.com/pyecharts/pyecharts) .*
#
# *Note.建议本程序在参看https://github.com/pyecharts/pyecharts 的安装步骤后再运行； 本程序所有的例子都是从官方提供的样例代码[GitHub](https://github.com/pyecharts/pyecharts-gallery)中提取的,如果对某个API有疑问建议在IDE里面查看*
#
# *Echart类型图种大全:https://echarts.apache.org/examples/zh/#chart-type-line pyecharts图导入到ppt中的方法:https://baijiahao.baidu.com/s?id=1663839456876951842&wfr=spider&for=pc.*
#
# *作者: LBQ; 时间:2020/7/24. 邮箱:779660843@qq.com*

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
    #.render("funnel_base.html")
)
c.load_javascript()
c.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6f9c29b7425c49ec9635870200b2e9e3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6f9c29b7425c49ec9635870200b2e9e3 = echarts.init(
#                     document.getElementById('6f9c29b7425c49ec9635870200b2e9e3'), 'white', {renderer: 'canvas'});
#                 var option_6f9c29b7425c49ec9635870200b2e9e3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 31
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 55
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 108
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91d1\u6bdb",
#                 "\u6cf0\u8fea",
#                 "\u5409\u5a03\u5a03",
#                 "\u7267\u7f8a\u72ac",
#                 "\u54c8\u58eb\u5947",
#                 "\u67ef\u57fa",
#                 "\u8428\u6469\u8036"
#             ],
#             "selected": {
#                 "\u54c8\u58eb\u5947": true,
#                 "\u8428\u6469\u8036": true,
#                 "\u6cf0\u8fea": true,
#                 "\u91d1\u6bdb": true,
#                 "\u7267\u7f8a\u72ac": true,
#                 "\u5409\u5a03\u5a03": true,
#                 "\u67ef\u57fa": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6f9c29b7425c49ec9635870200b2e9e3.setOption(option_6f9c29b7425c49ec9635870200b2e9e3);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Funnel

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.baidu.com/examples/editor.html?c=funnel

目前无法实现的功能:

1、暂时无法对漏斗图的长宽等范围操作进行修改
"""
x_data = ["展现", "点击", "访问", "咨询", "订单"]
y_data = [100, 80, 60, 40, 20]

data = [[x_data[i], y_data[i]] for i in range(len(x_data))]

fc = (
    Funnel()
    .add(
        series_name="",
        data_pair=data,
        gap=2,
        tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"),
        label_opts=opts.LabelOpts(is_show=True, position="inside"),
        itemstyle_opts=opts.ItemStyleOpts(border_color="#fff", border_width=1),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="漏斗图", subtitle="纯属虚构"))
    #.render("funnel_chart.html")
)
fc.load_javascript()
fc.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="361d857542e14ddea2fdea63ecace8d2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_361d857542e14ddea2fdea63ecace8d2 = echarts.init(
#                     document.getElementById('361d857542e14ddea2fdea63ecace8d2'), 'white', {renderer: 'canvas'});
#                 var option_361d857542e14ddea2fdea63ecace8d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "data": [
#                 {
#                     "name": "\u5c55\u73b0",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u70b9\u51fb",
#                     "value": 80
#                 },
#                 {
#                     "name": "\u8bbf\u95ee",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u54a8\u8be2",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u8ba2\u5355",
#                     "value": 20
#                 }
#             ],
#             "sort": "descending",
#             "gap": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b} : {c}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "borderColor": "#fff",
#                 "borderWidth": 1
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c55\u73b0",
#                 "\u8ba2\u5355",
#                 "\u54a8\u8be2",
#                 "\u70b9\u51fb",
#                 "\u8bbf\u95ee"
#             ],
#             "selected": {
#                 "\u5c55\u73b0": true,
#                 "\u70b9\u51fb": true,
#                 "\u8bbf\u95ee": true,
#                 "\u54a8\u8be2": true,
#                 "\u8ba2\u5355": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe",
#             "subtext": "\u7eaf\u5c5e\u865a\u6784",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_361d857542e14ddea2fdea63ecace8d2.setOption(option_361d857542e14ddea2fdea63ecace8d2);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker


fl = (
    Funnel()
    .add(
        "商品",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Label（inside)"))
    #.render("funnel_label_inside.html")
)
fl.load_javascript()
fl.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8756dd8d216f410ea76d25a9725a2225" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8756dd8d216f410ea76d25a9725a2225 = echarts.init(
#                     document.getElementById('8756dd8d216f410ea76d25a9725a2225'), 'white', {renderer: 'canvas'});
#                 var option_8756dd8d216f410ea76d25a9725a2225 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 138
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 149
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u6cb3\u9a6c",
#                 "\u5927\u8c61",
#                 "\u87d2\u86c7",
#                 "\u5154\u5b50",
#                 "\u8001\u864e"
#             ],
#             "selected": {
#                 "\u6cb3\u9a6c": true,
#                 "\u87d2\u86c7": true,
#                 "\u8001\u864e": true,
#                 "\u5927\u8c61": true,
#                 "\u5154\u5b50": true,
#                 "\u718a\u732b": true,
#                 "\u72ee\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Funnel-Label\uff08inside)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_8756dd8d216f410ea76d25a9725a2225.setOption(option_8756dd8d216f410ea76d25a9725a2225);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

fs = (
    Funnel()
    .add(
        "商品",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        sort_="ascending",
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Sort（ascending）"))
    #.render("funnel_sort_ascending.html")
)
fs.load_javascript()
fs.render_notebook()
# Out:
# /home/fisadm/anaconda3/envs/detectron2/lib/python3.7/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="177af75542eb41fdb958a93f204c0eeb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_177af75542eb41fdb958a93f204c0eeb = echarts.init(
#                     document.getElementById('177af75542eb41fdb958a93f204c0eeb'), 'white', {renderer: 'canvas'});
#                 var option_177af75542eb41fdb958a93f204c0eeb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 85
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 148
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 114
#                 }
#             ],
#             "sort": "ascending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u718a\u732b",
#                 "\u72ee\u5b50",
#                 "\u6cb3\u9a6c",
#                 "\u5927\u8c61",
#                 "\u87d2\u86c7",
#                 "\u5154\u5b50",
#                 "\u8001\u864e"
#             ],
#             "selected": {
#                 "\u6cb3\u9a6c": true,
#                 "\u87d2\u86c7": true,
#                 "\u8001\u864e": true,
#                 "\u5927\u8c61": true,
#                 "\u5154\u5b50": true,
#                 "\u718a\u732b": true,
#                 "\u72ee\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Funnel-Sort\uff08ascending\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_177af75542eb41fdb958a93f204c0eeb.setOption(option_177af75542eb41fdb958a93f204c0eeb);
#         });
#     </script>
